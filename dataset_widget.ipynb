# %%
# %load_ext autoreload
# %autoreload 2
# %env ANYWIDGET_HMR=1
# Out:
# env: ANYWIDGET_HMR=1

# %%
TOKEN = ""

# %%
from scicat_widget import DatasetUploadWidget, dataset_upload_widget
import IPython.display
from scitacean import Client
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from scicat_widget import DatasetUploadWidget, dataset_upload_widget
#       2 import IPython.display
#       3 from scitacean import Client
#
# File ~/Work/cat/widget/src/scicat_widget/__init__.py:3
#       1 import importlib.metadata
# ----> 3 from ._widgets import DatasetUploadWidget, dataset_upload_widget
#       5 try:
#       6     __version__ = importlib.metadata.version("scicat_widget")
#
# File ~/Work/cat/widget/src/scicat_widget/_widgets.py:14
#      12 from scitacean import Client, File, ScicatCommError
#      13 from scitacean.ontology import expands_techniques
# ---> 14 from anywidget.serializers import unpack_models
#      16 from ._logging import get_logger
#      17 from ._model import Instrument, ProposalOverview
#
# ModuleNotFoundError: No module named 'anywidget.serializers'

# %%
# client = Client.from_token("staging.ess", token=TOKEN)

# %%
w = dataset_upload_widget(client=None, skip_confirm=True)
IPython.display.display(w)
# IPython.display.display(w.output)
