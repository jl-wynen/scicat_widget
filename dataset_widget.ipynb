# %%
# %load_ext autoreload
# %autoreload 2
# %env ANYWIDGET_HMR=1
# Out:
# env: ANYWIDGET_HMR=1

# %%
TOKEN = ""

# %%
from scicat_widget import DatasetUploadWidget
from scitacean import Client  # noqa: F401, RUF100
from scitacean.testing.client import FakeClient  # noqa: F401, RUF100
from scitacean.testing.transfer import FakeFileTransfer  # noqa: F401, RUF100

# %%
# client = Client.from_token("staging.ess", token=TOKEN)
transfer = FakeFileTransfer()
client = FakeClient.without_login("staging.ess", file_transfer=transfer)
# Out:
# SFTP is not available, only file transfers on the same system are supported. Error: No module named 'paramiko'

# %%
w = DatasetUploadWidget(client, skip_confirm=False)
w
# Out:
# Failed to download initial data for user: Using `call_endpoint` is not supported by FakeClient. Called with cmd='GET' url='users/my/identity' operation='get_user_info' data=None params=None
# VBox(children=(<scicat_widget._widgets.DatasetUploadWidget object at 0x7f5610f47750>, Output(_dom_classes=('ce…

# %% [markdown]
# Uploaded datasets:

# %%
client.datasets.keys()
# Out:
# dict_keys([])

# %%
transfer.files.keys()
# Out:
# dict_keys([])
