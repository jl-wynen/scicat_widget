# %%
# %load_ext autoreload
# %autoreload 2
# %env ANYWIDGET_HMR=1
# Out:
# env: ANYWIDGET_HMR=1

# %%
from scicat_widget import DatasetWidget

# %%
w = DatasetWidget()
w

# %%
def callback(widget, content, buffers):
    print('got back', content)

w.on_msg(callback)

# %%
w.send({'type': 'retrieve'})
