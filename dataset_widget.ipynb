# %%
# %load_ext autoreload
# %autoreload 2
# %env ANYWIDGET_HMR=1

# %%
TOKEN = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.._aCDwhHp2N2IE5tj8ZhSBJ5gC7lPw-YLKMF9Pm11Fvk"

# %%
from scicat_widget import DatasetUploadWidget, dataset_upload_widget
import IPython.display
from scitacean import Client
from scitacean.testing.client import FakeClient

# %%
# client = Client.from_token("staging.ess", token=TOKEN)
client = FakeClient.without_login("staging.ess")

# %%
w = dataset_upload_widget(client=client, skip_confirm=False)
w
