# %%
# %load_ext autoreload
# %autoreload 2
# %env ANYWIDGET_HMR=1

# %%
TOKEN = ""

# %%
from scicat_widget import DatasetUploadWidget, dataset_upload_widget
from scitacean import Client

# %%
client = Client.from_token("staging.ess", token=TOKEN)

# %%
w = dataset_upload_widget(client=client)
w

# %%
def callback(widget, content, buffers):
    print('got back', content)


w.on_msg(callback)
