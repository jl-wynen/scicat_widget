# %%
# %load_ext autoreload
# %autoreload 2
# %env ANYWIDGET_HMR=1
# Out:
# env: ANYWIDGET_HMR=1

# %%
from scicat_widget import SearchDropdown
options = [
  "diffraction",
  "powder diffraction",
  "sans",
  "small angle scattering",
  "small angle neutron scattering",
  "small angle x-ray scattering",
]
SearchDropdown(options=options)

# %%
from scicat_widget import Owners
o = Owners(owners=[{"name": "Own", "email": "Mail", "orcid": "123"}],
           pi={"name": "testo", "email": "test"})
o

# %%
print(o.owners)
print(o.pi)
# Out:
# [{'name': 'Own', 'email': 'Mail', 'orcid': '123'}]
# {'name': 'testo', 'email': 'test'}

# %%
def callback(widget, content, buffers):
    print(widget, content, buffers)

o.on_msg(callback)

# %%
o.send({'type': 'my-msg', 'data': 'foo'})
